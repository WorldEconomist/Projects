# %%
import os
from dotenv import load_dotenv

import pandas as pd
from sqlalchemy import create_engine, inspect

# %%
load_dotenv()
# Out:
# True

# %%
USER = os.getenv('DB_USER')
PASSWORD = os.getenv('DB_PASSWORD')
HOST = os.getenv('DB_HOST')
NAME = os.getenv('DB_NAME')

# %%
DATABASE_URI = f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}/{NAME}"

# %%
engine = create_engine(DATABASE_URI)

# %%
connection = engine.connect()

# %%
def select(sql):
    return pd.read_sql(sql, connection)

# %%
inspect(engine).get_table_names()
# Out:
# ['active_clients',
#  'cards',
#  'categories',
#  'events_data',
#  'offers',
#  'orders',
#  'orders_new']

# %% [markdown]
# # Задача:
#
# Есть таблица логов событий.
# Так вышло, что часть ютм меток при переходах между страницами не прокидывается.
# Это создает вопросы от продактов в стиле - "Почему в отчетах много переходов с пустыми ютм-метками?"
#
# Как мы можем решить эту проблему?
# (Может, подшаманить данные?)
#
# Или иными словами эта же задача:
# Заполнить пустые метки таким образом, чтобы при появлении у юзера события с меткой X всем последующим событиям этого же юзера с пустой меткой присваивалась метка X до появления новой непустой метки Y. После появления метки Y -  всем последующим событиям с пустой меткой присваивалась метка Y и т.д.
# Можно обработать только одну метку (например, utm_source).

# %%
sql = '''
      select * from events_data 
      '''
select(sql)
# Out:
#     user_id          event_name      event_timestamp utm_source utm_medium  \
# 0         1         first_visit  2023-07-07 13:51:55
# 1         1       session_start  2023-07-07 13:51:55
# 2         1           page_view  2023-07-07 13:51:55         vk        cpm
# 3         1              scroll  2023-07-07 13:52:26  vkontakte        cpm
# 4         1          form_start  2023-07-07 13:53:32  vkontakte        cpm
# 5         2     user_engagement  2023-07-07 13:53:48  vkontakte        cpm
# 6         2           page_view  2023-07-07 13:53:51
# 7         2  New telegram click  2023-07-07 13:53:51
# 8         2               click  2023-07-07 13:53:56
# 9         2  New telegram click  2023-07-07 13:53:57
# 10        2               click  2023-07-07 13:54:01
# 11        2              scroll  2023-07-07 13:54:01
# 12        2  New telegram click  2023-07-07 13:54:01
# 13        1               click  2023-07-07 13:54:06
# 14        1  New telegram click  2023-07-07 13:54:08  e.mail.ru   referral
# 15        1               click  2023-07-07 13:54:11
# 16        2        New vk click  2023-07-07 13:54:11
# 17        3               click  2023-07-07 13:54:12
# 18        3           page_view  2023-07-07 14:07:24    youtube   test_utm
# 19        1           page_view  2023-07-07 14:07:25
# 20        1              scroll  2023-07-07 14:07:28  e.mail.ru   referral
# 21        1               click  2023-07-07 14:07:29
# 22        2     user_engagement  2023-07-07 14:07:32  e.mail.ru   referral
#
#    utm_campaign
# 0
# 1
# 2       dnp1107
# 3       dnp1107
# 4       dnp1111
# 5       dnp1107
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 14   (referral)
# 15
# 16
# 17
# 18
# 19
# 20   (referral)
# 21
# 22   (referral)

# %%
sql = '''
        WITH cte AS (
            SELECT 
                *,
                ROW_NUMBER() OVER () AS rn
            FROM 
                events_data
        ),
        
        groupses AS (
            SELECT 
                *,
                SUM(CASE WHEN utm_source <> '' THEN 1 ELSE 0 END) OVER (
                    PARTITION BY user_id 
                    ORDER BY rn
                ) AS group_source,
                
                SUM(CASE WHEN utm_medium <> '' THEN 1 ELSE 0 END) OVER (
                    PARTITION BY user_id 
                    ORDER BY rn
                ) AS group_medium,
                
                SUM(CASE WHEN utm_campaign <> '' THEN 1 ELSE 0 END) OVER (
                    PARTITION BY user_id 
                    ORDER BY rn
                ) AS group_campaign
                
            FROM 
                cte
        )
        
        SELECT 
            user_id,
            event_name,
            event_timestamp,
            
            MAX(utm_source) OVER (
                PARTITION BY user_id, group_source
            ) AS utm_source,
            
            MAX(utm_medium) OVER (
                PARTITION BY user_id, group_medium
            ) AS utm_medium,
            
            MAX(utm_campaign) OVER (
                PARTITION BY user_id, group_campaign
            ) AS utm_campaign
            
        FROM 
            groupses
        ORDER BY 
            rn      
      '''
select(sql)
# Out:
#     user_id          event_name      event_timestamp utm_source utm_medium  \
# 0         1         first_visit  2023-07-07 13:51:55
# 1         1       session_start  2023-07-07 13:51:55
# 2         1           page_view  2023-07-07 13:51:55         vk        cpm
# 3         1              scroll  2023-07-07 13:52:26  vkontakte        cpm
# 4         1          form_start  2023-07-07 13:53:32  vkontakte        cpm
# 5         2     user_engagement  2023-07-07 13:53:48  vkontakte        cpm
# 6         2           page_view  2023-07-07 13:53:51  vkontakte        cpm
# 7         2  New telegram click  2023-07-07 13:53:51  vkontakte        cpm
# 8         2               click  2023-07-07 13:53:56  vkontakte        cpm
# 9         2  New telegram click  2023-07-07 13:53:57  vkontakte        cpm
# 10        2               click  2023-07-07 13:54:01  vkontakte        cpm
# 11        2              scroll  2023-07-07 13:54:01  vkontakte        cpm
# 12        2  New telegram click  2023-07-07 13:54:01  vkontakte        cpm
# 13        1               click  2023-07-07 13:54:06  vkontakte        cpm
# 14        1  New telegram click  2023-07-07 13:54:08  e.mail.ru   referral
# 15        1               click  2023-07-07 13:54:11  e.mail.ru   referral
# 16        2        New vk click  2023-07-07 13:54:11  vkontakte        cpm
# 17        3               click  2023-07-07 13:54:12
# 18        3           page_view  2023-07-07 14:07:24    youtube   test_utm
# 19        1           page_view  2023-07-07 14:07:25  e.mail.ru   referral
# 20        1              scroll  2023-07-07 14:07:28  e.mail.ru   referral
# 21        1               click  2023-07-07 14:07:29  e.mail.ru   referral
# 22        2     user_engagement  2023-07-07 14:07:32  e.mail.ru   referral
#
#    utm_campaign
# 0
# 1
# 2       dnp1107
# 3       dnp1107
# 4       dnp1111
# 5       dnp1107
# 6       dnp1107
# 7       dnp1107
# 8       dnp1107
# 9       dnp1107
# 10      dnp1107
# 11      dnp1107
# 12      dnp1107
# 13      dnp1111
# 14   (referral)
# 15   (referral)
# 16      dnp1107
# 17
# 18
# 19   (referral)
# 20   (referral)
# 21   (referral)
# 22   (referral)

# %%
connection.close()
